# %% [markdown]
# # EMSI BG JOB BOARD SCRAPING PROJECT - Dated 3/7/22

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from seleniumwire import webdriver
import ast
import os

# %% [markdown]
# ### Step 1: Check for access
#
# I will first check and see if I can easy access this website using a simple requests.get

# %%
url = 'https://www.economicmodeling.com/open-positions/'

requests.get(url).text
# Out:
# '<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body>\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %% [markdown]
# Oh no! I've been request blocked! I will maybe have to change my approach to accessing this website

# %%
headers = {
    'User-Agent':'not-suspicious-bot'
}

job_board_html = requests.get(url, headers=headers)
job_board_html
# Out:
# <Response [200]>

# %% [markdown]
# Now that's more like it.

# %% [markdown]
# ### Step 2: Check for an API
#
# I can certainly do this by hand by inspecting the network tab on my browser, but I'm going to let python handle it for me. Selenium wire allows me to check for the requests of a website, which is what I might do manually if I wanted to check whether or not a website has an api. The following code simply returns any url with 'api' in it.

# %%
#create a new instance of chrome driver with the appropriate options
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--ignore-certificate-errors-spki-list')
chrome_options.add_argument('--ignore-ssl-errors')

#have to put your local path to the driver!
driver = webdriver.Chrome(executable_path=r"[INSERT PATH]chromedriver.exe", options=chrome_options)


#grab the emsi page
driver.get(url)

#create a blank array to store responses
requests_array = []

#grab requests from requests
for request in driver.requests:
    if request.response:
        requests_array.append(request.url)

# %%
#now check and see if there is anything with 'api'
requests_df = pd.DataFrame(requests_array)
api_df = requests_df.loc[requests_df[0].str.contains('api', case=False)].reset_index()
api_df
# Out:
#    index                                                  0
# 0     40  https://www.economicmodeling.com/wp-content/up...
# 1     41  https://www.economicmodeling.com/wp-content/up...
# 2    128  https://api.lever.co/v0/postings/economicmodel...
# 3    149  https://api.hubspot.com/livechat-public/v1/mes...
# 4    169  https://api.hubspot.com/cartographer/v1/rhumb?...
# 5    172  https://api.hubspot.com/livechat-public/v1/bot...

# %% [markdown]
# I've now got 6 different urls that all contain the substring "api." I'm going to print each one to see if I can find some more information.

# %%
for api in api_df[0]:
    print(api)
    print()
# Out:
# https://www.economicmodeling.com/wp-content/uploads/2021/04/icon-api-cloud.svg
#
# https://www.economicmodeling.com/wp-content/uploads/2021/04/icon-indigo-api-cloud.svg
#
# https://api.lever.co/v0/postings/economicmodeling?group=team&mode=json
#
# https://api.hubspot.com/livechat-public/v1/message/public?portalId=4906807&conversations-embed=static-1.9719&mobile=false&messagesUtk=c90a0dee98ee492fb0b8b23577cdbe35&traceId=c90a0dee98ee492fb0b8b23577cdbe35
#
# https://api.hubspot.com/cartographer/v1/rhumb?hs_static_app=conversations-visitor-ui&hs_static_app_version=1.12180
#
# https://api.hubspot.com/livechat-public/v1/bots/public/bot/261426/welcomeMessages?hs_static_app=conversations-visitor-ui&hs_static_app_version=1.12180&conversations-visitor-ui=static-1.12180&traceId=c90a0dee98ee492fb0b8b23577cdbe35&sessionId=AMOaWbLeaohdcuL9W3YBTFs_b7QhmxLJ1pSYjcaD3qYNICgERRW-JFKB_ZGKSCzmZ_Z6ZLztZbEm7nqdwF52nePbD2-hLAkzbiNZd8lGzqOj-w8ZRsFlqJx1oeHCSr1ckhGRdVsijO9WBrRb9r_RABfV0Pxwl4xbMLddz1CEQutTqdCs29gk9mA

# %% [markdown]
# I see that the first two urls are .svg files, so I will ignore those, but the other urls might be what I'm looking for

# %%
for api in api_df[0][2:]:
    try: 
        print(api)
        print(pd.DataFrame(requests.get(api, headers=headers).json()))
        print()
    except Exception as e:
        print(e)
        print()
# Out:
# https://api.lever.co/v0/postings/economicmodeling?group=team&mode=json
#                     title                                           postings
# 0         Client Services  [{'additionalPlain': 'Emsi Burning Glass is an...
# 1      Data and Analytics  [{'additionalPlain': 'This position reports to...
# 2               Economics  [{'additionalPlain': 'At Emsi Burning Glass, w...
# 3             Engineering  [{'additionalPlain': 'Emsi Burning Glass is an...
# 4                 Finance  [{'additionalPlain': 'Emsi Burning Glass is an...
# 5                   Legal  [{'additionalPlain': 'Opportunities within Ems...
# 6               Marketing  [{'additionalPlain': 'Emsi Burning Glass is an...
# 7                 Product  [{'additionalPlain': 'Emsi Burning Glass is an...
# 8   Professional Services  [{'additionalPlain': 'Emsi Burning Glass is an...
# 9        Public Relations  [{'additionalPlain': 'Emsi Burning Glass is an...
# 10                  Sales  [{'additionalPlain': 'Emsi Burning Glass is an...
# 11         Talent Network  [{'additionalPlain': 'About Emsi
#
# We provide t...
#
# https://api.hubspot.com/livechat-public/v1/message/public?portalId=4906807&conversations-embed=static-1.9719&mobile=false&messagesUtk=c90a0dee98ee492fb0b8b23577cdbe35&traceId=c90a0dee98ee492fb0b8b23577cdbe35
# If using all scalar values, you must pass an index
#
# https://api.hubspot.com/cartographer/v1/rhumb?hs_static_app=conversations-visitor-ui&hs_static_app_version=1.12180
# [Errno Expecting value] <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
# <title>Error 405 Method Not Allowed</title>
# </head>
# <body><h2>HTTP ERROR 405</h2>
# <p>Problem accessing /cartographer/v1/rhumb. Reason:
# <pre>    Method Not Allowed</pre></p>
# </body>
# </html>
# : 0
#
# https://api.hubspot.com/livechat-public/v1/bots/public/bot/261426/welcomeMessages?hs_static_app=conversations-visitor-ui&hs_static_app_version=1.12180&conversations-visitor-ui=static-1.12180&traceId=c90a0dee98ee492fb0b8b23577cdbe35&sessionId=AMOaWbLeaohdcuL9W3YBTFs_b7QhmxLJ1pSYjcaD3qYNICgERRW-JFKB_ZGKSCzmZ_Z6ZLztZbEm7nqdwF52nePbD2-hLAkzbiNZd8lGzqOj-w8ZRsFlqJx1oeHCSr1ckhGRdVsijO9WBrRb9r_RABfV0Pxwl4xbMLddz1CEQutTqdCs29gk9mA
#                                              message  continueAfterMs
# 0  {'@type': 'INITIAL_MESSAGE', 'id': 'b69d08fb-3...             1350

# %% [markdown]
# Bingo, the third url seems to be what I was looking for, I'll double check and make sure.

# %%
pd.DataFrame(requests.get(api_df[0][2], headers=headers).json())
# Out:
#                     title                                           postings
# 0         Client Services  [{'additionalPlain': 'Emsi Burning Glass is an...
# 1      Data and Analytics  [{'additionalPlain': 'This position reports to...
# 2               Economics  [{'additionalPlain': 'At Emsi Burning Glass, w...
# 3             Engineering  [{'additionalPlain': 'Emsi Burning Glass is an...
# 4                 Finance  [{'additionalPlain': 'Emsi Burning Glass is an...
# 5                   Legal  [{'additionalPlain': 'Opportunities within Ems...
# 6               Marketing  [{'additionalPlain': 'Emsi Burning Glass is an...
# 7                 Product  [{'additionalPlain': 'Emsi Burning Glass is an...
# 8   Professional Services  [{'additionalPlain': 'Emsi Burning Glass is an...
# 9        Public Relations  [{'additionalPlain': 'Emsi Burning Glass is an...
# 10                  Sales  [{'additionalPlain': 'Emsi Burning Glass is an...
# 11         Talent Network  [{'additionalPlain': 'About Emsi
#
# We provide t...

# %% [markdown]
# ## Step 3: Organize the data
#
# It seems that there is a little bit to unpack here, so I'll get to separating the data out.

# %%
job_api = pd.DataFrame(requests.get('https://api.lever.co/v0/postings/economicmodeling?group=team&mode=json', headers=headers).json())
job_api = job_api.rename(columns={'title':'category'}) #the titles didn't really seem like job titles, more like categories
category_array = []

for index, row in job_api.iterrows():
    path = f"{row['category']}.csv"
    pd.DataFrame(row['postings']).to_csv(path, index=False)
    category_array.append(path)

# %% [markdown]
# Now let's see what I'm working with.

# %%
pd.read_csv(category_array[0], index_col=None)
# Out:
#                                      additionalPlain  \
# 0  Emsi Burning Glass is an equal opportunity emp...
#
#                                           additional  \
# 0  <div><i>Emsi Burning Glass is an equal opportu...
#
#                                           categories      createdAt  \
# 0  {'commitment': 'Full Time', 'department': 'Edu...  1641404323821
#
#                                     descriptionPlain  \
# 0  We are seeking a collaborative, detail-oriente...
#
#                                          description  \
# 0  <div>We are seeking a collaborative, detail-or...
#
#                                      id  \
# 0  390d26a0-e45c-4f6d-9bfd-ad7c50da188c
#
#                                                lists  \
# 0  [{'text': 'In this role, you would: ', 'conten...
#
#                           text  \
# 0  Education Success Team Lead
#
#                                            hostedUrl  \
# 0  https://jobs.lever.co/economicmodeling/390d26a...
#
#                                             applyUrl
# 0  https://jobs.lever.co/economicmodeling/390d26a...

# %% [markdown]
# That's pretty good! Now I'm going to pick out what I want and leave out any fluff.

# %%
final_array = []
for category in category_array:
    #these are the columns I want from the json output
    final_df = pd.read_csv(category, index_col=None)[['text', 'descriptionPlain', 'categories', 'hostedUrl']]

    final_df['categories'] = final_df['categories'].apply(lambda x: ast.literal_eval(x).get('location'))
    #categories column itself is json, but isn't formatted; ast is used to help format and interpret as json

    final_df.rename(columns={'categories':'location', 'text':'job_title', 'descriptionPlain':'description'}, inplace=True)
    final_df['department'] = category.replace('.csv', '')
    final_array.append(final_df)
    os.remove(category)
pd.concat(final_array).reset_index(drop=True).to_csv('job_listings.csv', index=False)

# %% [markdown]
# And that should do it! The final product will be a csv file titled job_listings.csv
#
# The column names in the csv file are as follows: job_title,	description, location, hostedUrl, department

# %%
pd.read_csv('job_listings.csv')
# Out:
#                                   job_title  \
# 0               Education Success Team Lead
# 1                              Data Curator
# 2               Data Engineer, Web Scraping
# 3                            Data Scientist
# 4                Director of Data Analytics
# 5                 Machine Learning Engineer
# 6                     Senior Data Scientist
# 7                         Software Engineer
# 8       Thought Leadership Research Analyst
# 9                             API Developer
# 10                 Full Stack Web Developer
# 11                   Lead Software Engineer
# 12                                Bookeeper
# 13         Finance Administrative Assistant
# 14                        Financial Analyst
# 15                        Senior Accountant
# 16                Junior Corporate Attorney
# 17              Paralegal / Legal Assistant
# 18                        Marketing Manager
# 19           Cloud Delivery Product Manager
# 20                      Jr. Product Manager
# 21                          Product Manager
# 22                          Product Manager
# 23                       Product Specialist
# 24                 Software Product Manager
# 25                     Sr. Product Designer
# 26                     API Support Engineer
# 27                       Consulting Analyst
# 28                         Research Analyst
# 29                         Research Analyst
# 30                  Research Analyst Intern
# 31                            Research Lead
# 32                        Senior Consultant
# 33                     Social Media Manager
# 34  Account Executive, Economic Development
# 35             Enterprise Account Executive
# 36                     Solutions Consultant
# 37                 Join Our Talent Network!
#
#                                           description  \
# 0   We are seeking a collaborative, detail-oriente...
# 1   A Data Curator at Emsi BG is responsible for e...
# 2   Emsi Burning Glass is looking for a talented D...
# 3   A Data Scientist at Emsi Burning Glass works w...
# 4   The Director of Data Analytics leads data scie...
# 5   At Emsi Burning Glass, Machine Learning Engine...
# 6   The Senior Data Scientist at Emsi Burning Glas...
# 7   Emsi Burning Glass is looking for a skilled so...
# 8   We seek a Research Analyst to join our Thought...
# 9   Emsi Burning Glass is a trusted advisor on lab...
# 10  Emsi is a trusted advisor on labor market info...
# 11  As a lead software engineer at EmsiBG, you’d b...
# 12  The Bookkeeper roles at Emsi Burning Glass man...
# 13  \n\nOverview\n\nThe Finance Administrative Ass...
# 14  The Financial Analyst is part of the Emsi Burn...
# 15  The role of the Senior Accountant primarily co...
# 16  At Emsi Burning Glass, we strive to create a j...
# 17  At Emsi Burning Glass, we strive to create a j...
# 18  Emsi Burning Glass is searching for a full-tim...
# 19  The Cloud Delivery Product Manager will be res...
# 20  Emsi Burning Glass, the leader in labor market...
# 21  Emsi Burning Glass, the leader in labour marke...
# 22  The Community Insights Product Team at Emsi Bu...
# 23  Emsi Burning Glass, the leader in labor market...
# 24  Emsi Burning Glass is a trusted advisor on lab...
# 25  The Education Product & Design Team at Emsi Bu...
# 26  Emsi Burning Glass is seeking a hard-working a...
# 27  The Research Analyst at EMSI Burning Glass wor...
# 28  The Research Analyst at Emsi Burning Glass wor...
# 29  At Emsi Burning Glass, we strive to create a j...
# 30  The Research Analyst Intern at Emsi Burning Gl...
# 31  At Emsi Burning Glass, we strive to create a j...
# 32  The Senior Consultant at Emsi Burning Glass wo...
# 33  Emsi Burning Glass is searching for a talented...
# 34  Emsi Burning Glass is hiring a results-driven ...
# 35  Emsi Burning Glass is hiring results-driven En...
# 36  Emsi Burning Glass (EBG) is looking for a tale...
# 37  Didn't find a job posting, but want to keep in...
#
#                       location  \
# 0                   Moscow, ID
# 1                   Moscow, ID
# 2   Remote (Work From Home) US
# 3   Remote (Work From Home) US
# 4        Boston, Massachusetts
# 5   Remote (Work From Home) US
# 6   Remote (Work From Home) US
# 7                   Moscow, ID
# 8        Boston, Massachusetts
# 9                   Moscow, ID
# 10                  Moscow, ID
# 11                  Moscow, ID
# 12                  Moscow, ID
# 13                  Moscow, ID
# 14                  Moscow, ID
# 15                  Moscow, ID
# 16                  Moscow, ID
# 17                  Moscow, ID
# 18                  Moscow, ID
# 19                  Moscow, ID
# 20  Remote (Work From Home) US
# 21  Basingstoke, Hampshire, UK
# 22  Remote (Work From Home) US
# 23                  Moscow, ID
# 24                  Moscow, ID
# 25  Remote (Work From Home) US
# 26                  Moscow, ID
# 27       Boston, Massachusetts
# 28       Boston, Massachusetts
# 29       Boston, Massachusetts
# 30       Boston, Massachusetts
# 31       Boston, Massachusetts
# 32       Boston, Massachusetts
# 33                  Moscow, ID
# 34                  Moscow, ID
# 35                  Moscow, ID
# 36                  Moscow, ID
# 37                  Moscow, ID
#
#                                             hostedUrl             department
# 0   https://jobs.lever.co/economicmodeling/390d26a...        Client Services
# 1   https://jobs.lever.co/economicmodeling/d5ff570...     Data and Analytics
# 2   https://jobs.lever.co/economicmodeling/1411c67...     Data and Analytics
# 3   https://jobs.lever.co/economicmodeling/e846f31...     Data and Analytics
# 4   https://jobs.lever.co/economicmodeling/932d576...     Data and Analytics
# 5   https://jobs.lever.co/economicmodeling/f75b465...     Data and Analytics
# 6   https://jobs.lever.co/economicmodeling/6c85559...     Data and Analytics
# 7   https://jobs.lever.co/economicmodeling/e9fa059...     Data and Analytics
# 8   https://jobs.lever.co/economicmodeling/90e27c9...              Economics
# 9   https://jobs.lever.co/economicmodeling/d2f21e2...            Engineering
# 10  https://jobs.lever.co/economicmodeling/c738640...            Engineering
# 11  https://jobs.lever.co/economicmodeling/2638f99...            Engineering
# 12  https://jobs.lever.co/economicmodeling/a89ea22...                Finance
# 13  https://jobs.lever.co/economicmodeling/b0e9c4d...                Finance
# 14  https://jobs.lever.co/economicmodeling/e6f7ef8...                Finance
# 15  https://jobs.lever.co/economicmodeling/4594e8c...                Finance
# 16  https://jobs.lever.co/economicmodeling/fb5f705...                  Legal
# 17  https://jobs.lever.co/economicmodeling/2d9781f...                  Legal
# 18  https://jobs.lever.co/economicmodeling/e52d24a...              Marketing
# 19  https://jobs.lever.co/economicmodeling/5c9bc83...                Product
# 20  https://jobs.lever.co/economicmodeling/5731ab4...                Product
# 21  https://jobs.lever.co/economicmodeling/0086b5a...                Product
# 22  https://jobs.lever.co/economicmodeling/6d71521...                Product
# 23  https://jobs.lever.co/economicmodeling/c860964...                Product
# 24  https://jobs.lever.co/economicmodeling/1454d90...                Product
# 25  https://jobs.lever.co/economicmodeling/f2ec98d...                Product
# 26  https://jobs.lever.co/economicmodeling/88ed06a...  Professional Services
# 27  https://jobs.lever.co/economicmodeling/e3c188d...  Professional Services
# 28  https://jobs.lever.co/economicmodeling/7fb034c...  Professional Services
# 29  https://jobs.lever.co/economicmodeling/a8e0ddf...  Professional Services
# 30  https://jobs.lever.co/economicmodeling/3737fac...  Professional Services
# 31  https://jobs.lever.co/economicmodeling/2a1d053...  Professional Services
# 32  https://jobs.lever.co/economicmodeling/58606b1...  Professional Services
# 33  https://jobs.lever.co/economicmodeling/4db5640...       Public Relations
# 34  https://jobs.lever.co/economicmodeling/33affe9...                  Sales
# 35  https://jobs.lever.co/economicmodeling/d97bf37...                  Sales
# 36  https://jobs.lever.co/economicmodeling/4bdc81e...                  Sales
# 37  https://jobs.lever.co/economicmodeling/ad5f495...         Talent Network
